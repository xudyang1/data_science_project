# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d0c52cb-7c88-422e-a65d-56181945b3e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d0c52cb-7c88-422e-a65d-56181945b3e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving education.csv to education.csv
# Saving income.csv to income.csv
# Saving police_killings_test.csv to police_killings_test.csv
# Saving police_killings_train.csv to police_killings_train.csv
# Saving poverty.csv to poverty.csv
# Saving share_race_by_city.csv to share_race_by_city.csv

# %%
# load files
edu = pd.read_csv('education.csv', engine='python')
income = pd.read_csv('income.csv', engine='python')
train = pd.read_csv('police_killings_train.csv', engine='python')
test = pd.read_csv('police_killings_test.csv', engine='python')
poverty = pd.read_csv('poverty.csv', engine='python')
race = pd.read_csv('share_race_by_city.csv', engine='python')

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2028 entries, 0 to 2027
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2028 non-null   int64
#  1   name                     2028 non-null   object
#  2   date                     2028 non-null   object
#  3   manner_of_death          2028 non-null   object
#  4   armed                    2022 non-null   object
#  5   age                      1991 non-null   float64
#  6   gender                   2028 non-null   object
#  7   race                     1937 non-null   object
#  8   city                     2028 non-null   object
#  9   state                    2028 non-null   object
#  10  signs_of_mental_illness  2028 non-null   bool
#  11  threat_level             2028 non-null   object
#  12  flee                     2001 non-null   object
#  13  body_camera              2028 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 194.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       507 non-null    int64
#  1   name                     507 non-null    object
#  2   date                     507 non-null    object
#  3   manner_of_death          507 non-null    object
#  4   armed                    504 non-null    object
#  5   age                      467 non-null    float64
#  6   gender                   507 non-null    object
#  7   race                     403 non-null    object
#  8   city                     507 non-null    object
#  9   state                    507 non-null    object
#  10  signs_of_mental_illness  507 non-null    bool
#  11  threat_level             507 non-null    object
#  12  flee                     469 non-null    object
#  13  body_camera              507 non-null    bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 48.6+ KB

# %%
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
# column name conformity
race.rename(columns={'Geographic area': 'Geographic Area'},inplace=True)
race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic Area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
# merge poverty, edu, race, and income based on Geographic Area and City
keys = ['Geographic Area', 'City']
merged = pd.merge(edu, income,on=keys)
merged = pd.merge(merged, poverty, on=keys)
merged = pd.merge(merged, race, on=keys)
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29115 entries, 0 to 29114
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic Area        29115 non-null  object
#  1   City                   29115 non-null  object
#  2   percent_completed_hs   29115 non-null  object
#  3   Median Income          29064 non-null  object
#  4   poverty_rate           29115 non-null  object
#  5   share_white            29115 non-null  object
#  6   share_black            29115 non-null  object
#  7   share_native_american  29115 non-null  object
#  8   share_asian            29115 non-null  object
#  9   share_hispanic         29115 non-null  object
# dtypes: object(10)
# memory usage: 2.4+ MB

# %%
# convert strings to numeric data and set all non-sense data to null
target = merged.iloc[:,2:10]
for columnName in target:
    merged[columnName] = pd.to_numeric(merged[columnName], errors='coerce')
merged.isnull().sum()
# Out:
# Geographic Area             0
# City                        0
# percent_completed_hs      191
# Median Income            1905
# poverty_rate              195
# share_white                19
# share_black                19
# share_native_american      19
# share_asian                19
# share_hispanic             19
# dtype: int64

# %%
# mean value interpolation: fill missing data with mean value of the state that the data belongs to
merged = merged.fillna(merged.groupby('Geographic Area').transform(lambda x: x.fillna(x.mean())))
merged.isnull().sum()
# merged.dtypes
# Out:
# Geographic Area          0
# City                     0
# percent_completed_hs     0
# Median Income            0
# poverty_rate             0
# share_white              0
# share_black              0
# share_native_american    0
# share_asian              0
# share_hispanic           0
# dtype: int64

# %%
# rename columns for later work
merged.rename(columns={'Geographic Area': 'state', 'City': 'city'}, inplace=True)
merged
# Out:
#       state                    city  ...  share_asian  share_hispanic
# 0        AL              Abanda CDP  ...          0.0             1.6
# 1        AL          Abbeville city  ...          1.0             3.1
# 2        AL         Adamsville city  ...          0.3             2.3
# 3        AL            Addison town  ...          0.1             0.4
# 4        AL              Akron town  ...          0.0             0.3
# ...     ...                     ...  ...          ...             ...
# 29110    WY  Woods Landing-Jelm CDP  ...          2.1             0.0
# 29111    WY            Worland city  ...          0.6            16.6
# 29112    WY             Wright town  ...          0.2             6.2
# 29113    WY              Yoder town  ...          0.0             4.0
# 29114    WY           Y-O Ranch CDP  ...          0.0            11.8
#
# [29115 rows x 10 columns]

# %% [markdown]
# ### Exploring correlations

# %%
ex=merged
row['Killed']=merged.groupby(["state", "city"]).size()
row
# Out:
# state                                                                   AL
# city                                                         Saraland city
# percent_completed_hs                                                  85.4
# Median Income                                                        52621
# poverty_rate                                                          11.2
# share_white                                                           83.7
# share_black                                                             12
# share_native_american                                                  0.8
# share_asian                                                            0.6
# share_hispanic                                                         2.5
# Killed                   state  city
# AK     Adak city...
# Name: 468, dtype: object

# %%
plt.subplots(figsize=(8, 5))
sns.heatmap(merged.drop(['state', 'city'],axis=1).corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# ##EDA

# %%
train
# Out:
#         id                   name  ...         flee body_camera
# 0        3             Tim Elliot  ...  Not fleeing       False
# 1        4       Lewis Lee Lembke  ...  Not fleeing       False
# 2        5     John Paul Quintero  ...  Not fleeing       False
# 3        8        Matthew Hoffman  ...  Not fleeing       False
# 4        9      Michael Rodriguez  ...  Not fleeing       False
# ...    ...                    ...  ...          ...         ...
# 2023  2256   Jeremy Lopez-Robledo  ...         Foot        True
# 2024  2257    Jonathan David Sper  ...  Not fleeing       False
# 2025  2258  Jose Efrain Rodriguez  ...  Not fleeing       False
# 2026  2259          Ramon Milanez  ...          Car       False
# 2027  2260       Micah R. Lambert  ...          Car       False
#
# [2028 rows x 14 columns]

# %%
summaries = train['armed'].unique()
summary_mapping = {key:i for key,i in zip(summaries, range(len(summaries)))}
summary_mapping
# Out:
# {'Taser': 21,
#  'air conditioner': 64,
#  'ax': 39,
#  'baseball bat': 41,
#  'baseball bat and fireplace poker': 36,
#  'baton': 49,
#  'bayonet': 55,
#  'bean-bag gun': 35,
#  'beer bottle': 34,
#  'blunt object': 24,
#  'box cutter': 12,
#  'brick': 40,
#  'carjack': 29,
#  'chain': 30,
#  'chain saw': 43,
#  "contractor's level": 31,
#  'cordless drill': 18,
#  'crossbow': 19,
#  'crowbar': 60,
#  'flagpole': 16,
#  'flashlight': 48,
#  'garden tool': 44,
#  'glass shard': 57,
#  'gun': 0,
#  'gun and knife': 38,
#  'guns and explosives': 17,
#  'hammer': 7,
#  'hand torch': 42,
#  'hatchet': 8,
#  'hatchet and gun': 52,
#  'knife': 4,
#  'lawn mower blade': 15,
#  'machete': 11,
#  'machete and gun': 62,
#  'meat cleaver': 27,
#  'metal hand tool': 23,
#  'metal object': 13,
#  'metal pipe': 22,
#  'metal pole': 20,
#  'metal rake': 59,
#  'metal stick': 25,
#  'motorcycle': 58,
#  'nail gun': 3,
#  nan: 28,
#  'oar': 61,
#  'pick-axe': 47,
#  'piece of wood': 54,
#  'pipe': 56,
#  'pitchfork': 51,
#  'pole': 46,
#  'pole and knife': 65,
#  'rock': 53,
#  'scissors': 45,
#  'screwdriver': 14,
#  'sharp object': 26,
#  'shovel': 6,
#  'spear': 50,
#  'stapler': 33,
#  'straight edge razor': 37,
#  'sword': 10,
#  'tire iron': 63,
#  'toy weapon': 2,
#  'unarmed': 1,
#  'undetermined': 9,
#  'unknown weapon': 32,
#  'vehicle': 5}

# %%
train.isnull().sum()
# Out:
# id                          0
# name                        0
# date                        0
# manner_of_death             0
# armed                       6
# age                        37
# gender                      0
# race                       91
# city                        0
# state                       0
# signs_of_mental_illness     0
# threat_level                0
# flee                       27
# body_camera                 0
# dtype: int64

# %% [markdown]
# ### Dangerous level

# %%
train.value_counts(["city", "state"])
# Out:
# city           state
# Los Angeles    CA       31
# Phoenix        AZ       24
# Houston        TX       22
# Chicago        IL       21
# Las Vegas      NV       16
#                         ..
# New City       NY        1
# New Castle     CO        1
# New Brunswick  NJ        1
# Neenah         WI        1
# Abingdon       MD        1
# Length: 1281, dtype: int64

# %%
train.value_counts(["state"])
# Out:
# state
# CA       340
# TX       186
# FL       122
# AZ        93
# CO        61
# OK        60
# GA        59
# NC        56
# OH        56
# IL        51
# LA        48
# MO        47
# TN        45
# NM        43
# WA        43
# PA        43
# AL        43
# NY        39
# VA        38
# SC        36
# KY        36
# IN        35
# NV        34
# MD        31
# OR        30
# MI        30
# NJ        28
# WI        28
# MN        28
# WV        23
# MA        21
# AR        20
# KS        19
# UT        18
# MS        17
# NE        15
# ID        14
# AK        11
# IA        10
# HI         9
# MT         9
# DC         9
# WY         8
# SD         7
# CT         6
# ME         5
# DE         5
# NH         5
# ND         3
# VT         3
# RI         2
# dtype: int64

# %% [markdown]
# ### Armed

# %%
train.value_counts(["armed"])
# Out:
# armed
# gun                    1114
# knife                   304
# unarmed                 148
# vehicle                 125
# undetermined             91
#                        ...
# stapler                   1
# hand torch                1
# pitchfork                 1
# tire iron                 1
# straight edge razor       1
# Length: 65, dtype: int64

# %%
plt.figure(figsize=(100,10))
ax = train.value_counts(["armed"]).head(50).plot(kind='bar', rot=0)
ax.set_xlabel("Weapon")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Age

# %% [markdown]
# #### By all race

# %%
train.value_counts(["age"])
# Out:
# age
# 31.0    79
# 25.0    77
# 36.0    77
# 29.0    74
# 30.0    62
#         ..
# 82.0     1
# 14.0     1
# 13.0     1
# 12.0     1
# 6.0      1
# Length: 71, dtype: int64

# %%
plt.figure(figsize=(40,10))
ax = train.value_counts(["age"]).head(50).plot(kind='bar', rot=0)
ax.set_xlabel("Age")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
train['race'].unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %% [markdown]
# #### Race A

# %%
train[train['race']=='A']
# Out:
#         id                         name  ...         flee body_camera
# 0        3                   Tim Elliot  ...  Not fleeing       False
# 69     346                  Matautu Nuu  ...  Not fleeing       False
# 155    195                   Hung Trieu  ...  Not fleeing       False
# 160    249                     Carl Lao  ...  Not fleeing       False
# 265    359          Joseph Jeremy Weber  ...  Not fleeing       False
# 303    397                     Lue Vang  ...  Not fleeing       False
# 337    430                Thong Kien Ma  ...  Not fleeing       False
# 468    601                   Ton Nguyen  ...  Not fleeing       False
# 685    879                 William Chau  ...  Not fleeing       False
# 686    817                      Tian Ma  ...  Not fleeing       False
# 766    900                    Kevin Lau  ...  Not fleeing       False
# 899   1043                   Tuan Hoang  ...          Car       False
# 945   1092     Mharloun Verdejo  Saycon  ...  Not fleeing       False
# 987   1134                     Tien Hua  ...  Not fleeing       False
# 1053  1208        Thongsavanh Vandarack  ...  Not fleeing       False
# 1203  1370                     Map Kong  ...  Not fleeing        True
# 1204  1372                   Sunny Chin  ...  Not fleeing       False
# 1293  1474           Sylasone Ackhavong  ...  Not fleeing       False
# 1312  1494                 Cin Lam Mung  ...  Not fleeing       False
# 1322  1508                Marion Habana  ...  Not fleeing        True
# 1347  1533         Thongsoune Vilaysane  ...          Car        True
# 1480  1670                   Barry Prak  ...         Foot       False
# 1481  1671                  Walden Dang  ...  Not fleeing       False
# 1560  1752              Limichael Shine  ...  Not fleeing        True
# 1747  1957            Michael L. Taylor  ...  Not fleeing       False
# 1790  2002                     Jun Wang  ...  Not fleeing       False
# 1845  2054                   Luke Smith  ...         Foot        True
# 1883  2098  Saif Nasser Mubarek Alameri  ...         Foot       False
# 1937  2166                  Zhonghua Li  ...  Not fleeing       False
# 1991  2217                 Sinuon Pream  ...  Not fleeing       False
# 1996  2214        Mohammad Azim Doudzai  ...  Not fleeing       False
#
# [31 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))

ax=train[train['race']=='A'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age A")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Race W

# %%
train[train['race']=='W']
# Out:
#         id                 name  ...         flee body_camera
# 1        4     Lewis Lee Lembke  ...  Not fleeing       False
# 3        8      Matthew Hoffman  ...  Not fleeing       False
# 5       11    Kenneth Joe Brown  ...  Not fleeing       False
# 7       15        Brock Nichols  ...  Not fleeing       False
# 8       16        Autumn Steele  ...  Not fleeing        True
# ...    ...                  ...  ...          ...         ...
# 2016  2249     Daniel D. Rogers  ...  Not fleeing        True
# 2017  2251    Bruce Altenburger  ...  Not fleeing       False
# 2020  2247   Dakota A. Lukecart  ...          Car       False
# 2024  2257  Jonathan David Sper  ...  Not fleeing       False
# 2027  2260     Micah R. Lambert  ...          Car       False
#
# [996 rows x 14 columns]

# %%
plt.figure(figsize=(400,10))

ax=train[train['race']=='W'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age W")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Race H

# %%
train[train['race']=='H']
# Out:
#         id                         name  ...         flee body_camera
# 2        5           John Paul Quintero  ...  Not fleeing       False
# 4        9            Michael Rodriguez  ...  Not fleeing       False
# 6       13          Kenneth Arnold Buck  ...          Car       False
# 20     325                Andy Martinez  ...  Not fleeing       False
# 22      43               Brian  Barbosa  ...  Not fleeing       False
# ...    ...                          ...  ...          ...         ...
# 2019  2246               Josue Gallardo  ...  Not fleeing       False
# 2022  2255  Antonio Arturo Perez Garcia  ...        Other       False
# 2023  2256         Jeremy Lopez-Robledo  ...         Foot        True
# 2025  2258        Jose Efrain Rodriguez  ...  Not fleeing       False
# 2026  2259                Ramon Milanez  ...          Car       False
#
# [348 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))

ax=train[train['race']=='H'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age H")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Race B

# %%
train[train['race']=='B']
# Out:
#         id                              name  ...         flee body_camera
# 9       17                   Leslie Sapp III  ...  Not fleeing       False
# 11      21                         Ron Sneed  ...  Not fleeing       False
# 12      22    Hashim Hanif Ibn Abdul-Rasheed  ...  Not fleeing       False
# 14      27  Omarr Julian Maximillian Jackson  ...         Foot        True
# 17      36               Artago Damon Howard  ...  Not fleeing       False
# ...    ...                               ...  ...          ...         ...
# 2003  2243                    Marquis Thomas  ...          Car       False
# 2009  2237                Ronnie Lee Shorter  ...  Not fleeing       False
# 2012  2234             Christopher Thompkins  ...  Not fleeing       False
# 2018  2253                      Armond Brown  ...  Not fleeing       False
# 2021  2254                    Arties Manning  ...          Car        True
#
# [507 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))

ax=train[train['race']=='B'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age B")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Race O

# %%
train[train['race']=='O']
# Out:
#         id                         name  ...         flee body_camera
# 38      68                Zaki Shinwary  ...  Not fleeing       False
# 327    418         Fridoon Zalbeg Nehad  ...  Not fleeing        True
# 332    428                  Nadir Soofi  ...  Not fleeing       False
# 352    449                Bruce Zalonka  ...  Not fleeing       False
# 387    491                  Feras Morad  ...  Not fleeing       False
# 524    649  Mohammad Youssef Abdulazeez  ...  Not fleeing       False
# 724    857                Robert Berger  ...  Not fleeing       False
# 731    865                 Philip Quinn  ...  Not fleeing       False
# 754    895                     Omar Ali  ...  Not fleeing       False
# 812    956               Kobvey Igbuhay  ...         Foot       False
# 833    979              Faisal Mohammad  ...         Foot       False
# 905   1050               Tashfeen Malik  ...          Car       False
# 906   1051                  Syed Farook  ...          Car       False
# 939   1084              Nephi  Leiataua  ...  Not fleeing       False
# 986   1133    Siolosega Velega-Nuufolau  ...  Not fleeing       False
# 1083  1242               Ronald Barawis  ...          Car       False
# 1095  1256             Scottie Yanagawa  ...  Not fleeing       False
# 1100  1260              Anthony Bertoni  ...  Not fleeing       False
# 1337  1529                 Derek J. Sam  ...  Not fleeing       False
# 1409  1597           Kalyp Allen Rapoza  ...  Not fleeing       False
# 1426  1608                  Omar Mateen  ...  Not fleeing        True
# 1435  1624           Mohammad Moghaddam  ...  Not fleeing       False
# 1533  1724                  BJ Medeiros  ...  Not fleeing       False
# 1690  1898                   Dahir Adan  ...  Not fleeing       False
# 1868  2083        Abdul Razak Ali Artan  ...  Not fleeing       False
# 1895  2115       Stephen Joshua Whitney  ...  Not fleeing       False
# 1982  2210              Hafez Abousamra  ...        Other       False
# 1987  2218              Cameron Johnson  ...          Car       False
#
# [28 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))

ax=train[train['race']=='O'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age O")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Race N

# %%
train[train['race']=='N']
# Out:
#         id                          name  ...         flee body_camera
# 64     348           Nicolas Leland Tewa  ...  Not fleeing       False
# 211    531                 Justin Fowler  ...          Car       False
# 296    393            Daniel Covarrubias  ...         Foot       False
# 438    563                Joe Charboneau  ...  Not fleeing       False
# 508    628                 Paul Castaway  ...         Foot       False
# 525    656                    Saige Hack  ...  Not fleeing       False
# 681    836                  Tristan Vent  ...  Not fleeing       False
# 684    816             Vincent J. Perdue  ...          Car       False
# 742    877     Patrick Stephen Lundstrom  ...  Not fleeing       False
# 1015  1166                   Herman Bean  ...  Not fleeing       False
# 1057  1213         Jacqueline D. Salyers  ...  Not fleeing       False
# 1077  1235               Raymond Gassman  ...  Not fleeing        True
# 1098  1255                Vincent Nageak  ...  Not fleeing       False
# 1131  1290                Sherrisa Homer  ...         Foot       False
# 1134  1305               Patricia Kruger  ...  Not fleeing       False
# 1236  1411               Loreal Tsingine  ...  Not fleeing        True
# 1352  1537                 Francis Clark  ...  Not fleeing        True
# 1369  1556                   Mark Nelson  ...  Not fleeing        True
# 1374  1560                  Verl Bedonie  ...         Foot        True
# 1403  1591      Hubert Thomas Burns, Jr.  ...  Not fleeing       False
# 1539  1730         Alvin R. Sylversmythe  ...  Not fleeing       False
# 1684  1889                  Jesse Beshaw  ...         Foot        True
# 1745  1951            Kheyanev Littledog  ...          NaN       False
# 1773  1988                   Renee Davis  ...  Not fleeing       False
# 1914  2137              Chassady LeClair  ...  Not fleeing       False
# 1985  2224  Jamison Christopher Anderson  ...  Not fleeing       False
# 2004  2245                 Melvin DeLong  ...  Not fleeing       False
#
# [27 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))

ax=train[train['race']=='N'].value_counts(["age"]).plot(kind='bar', rot=0)
ax.set_xlabel("Age N")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Race killed

# %%
train.value_counts(["race"])
# Out:
# race
# W       996
# B       507
# H       348
# A        31
# O        28
# N        27
# dtype: int64

# %% [markdown]
# ### Race ratio

# %%
killed_ratio=train['race'].value_counts(normalize=True) * 100
killed_ratio
# Out:
# W    51.419721
# B    26.174497
# H    17.965927
# A     1.600413
# O     1.445534
# N     1.393908
# Name: race, dtype: float64

# %%
merged.describe()
# Out:
#        percent_completed_hs  Median Income  ...   share_asian  share_hispanic
# count          29115.000000   29115.000000  ...  29115.000000    29115.000000
# mean              85.726993   51139.862514  ...      1.540946        9.287658
# std               11.812916   24159.593758  ...      4.282965       17.475072
# min                0.000000    4511.000000  ...      0.000000        0.000000
# 25%               81.000000   36250.000000  ...      0.000000        1.200000
# 50%               88.400000   45643.000000  ...      0.400000        2.900000
# 75%               93.500000   59313.469965  ...      1.200000        8.000000
# max              100.000000  244083.000000  ...     67.100000      100.000000
#
# [8 rows x 8 columns]

# %%
d = {'population': merged.drop(['percent_completed_hs','Median Income', 'poverty_rate'], axis = 1).describe()}
print(d)
# Out:
# {'population':         share_white   share_black  ...   share_asian  share_hispanic
# count  29115.000000  29115.000000  ...  29115.000000    29115.000000
# mean      83.210472      6.840125  ...      1.540946        9.287658
# std       21.661363     15.629311  ...      4.282965       17.475072
# min        0.000000      0.000000  ...      0.000000        0.000000
# 25%       78.500000      0.100000  ...      0.000000        1.200000
# 50%       92.500000      0.800000  ...      0.400000        2.900000
# 75%       96.900000      4.200000  ...      1.200000        8.000000
# max      100.000000    100.000000  ...     67.100000      100.000000
#
# [8 rows x 5 columns]}

# %% [markdown]
# ## Machine Learning algo

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %% [markdown]
# ### Data Spliting

# %%
Y_train = train["race"];
Y_train
# Out:
# 0       A
# 1       W
# 2       H
# 3       W
# 4       H
#        ..
# 2023    H
# 2024    W
# 2025    H
# 2026    H
# 2027    W
# Name: race, Length: 2028, dtype: object

# %%
X_train = train.drop(['race'], axis=1)
X_train
# Out:
#         id                   name  ...         flee body_camera
# 0        3             Tim Elliot  ...  Not fleeing       False
# 1        4       Lewis Lee Lembke  ...  Not fleeing       False
# 2        5     John Paul Quintero  ...  Not fleeing       False
# 3        8        Matthew Hoffman  ...  Not fleeing       False
# 4        9      Michael Rodriguez  ...  Not fleeing       False
# ...    ...                    ...  ...          ...         ...
# 2023  2256   Jeremy Lopez-Robledo  ...         Foot        True
# 2024  2257    Jonathan David Sper  ...  Not fleeing       False
# 2025  2258  Jose Efrain Rodriguez  ...  Not fleeing       False
# 2026  2259          Ramon Milanez  ...          Car       False
# 2027  2260       Micah R. Lambert  ...          Car       False
#
# [2028 rows x 13 columns]

# %%
Y_test = test["race"]
Y_test
# Out:
# 0        B
# 1        W
# 2        H
# 3        W
# 4        B
#       ...
# 502    NaN
# 503    NaN
# 504    NaN
# 505      B
# 506      B
# Name: race, Length: 507, dtype: object

# %%
X_test = test.drop(['race'], axis=1)
X_test
# Out:
#        id                      name  ...         flee body_camera
# 0    2261  Kevin Darnell Washington  ...  Not fleeing       False
# 1    2262    Donovan Paul Scheurich  ...  Not fleeing        True
# 2    2265         Josue Javier Diaz  ...          Car       False
# 3    2266          Kerry Lee Coomer  ...  Not fleeing        True
# 4    2267         Deaundre Phillips  ...          Car        True
# ..    ...                       ...  ...          ...         ...
# 502  2822          Rodney E. Jacobs  ...  Not fleeing       False
# 503  2813                     TK TK  ...          Car       False
# 504  2818        Dennis W. Robinson  ...          Car       False
# 505  2817             Isaiah Tucker  ...          Car        True
# 506  2815              Dwayne Jeune  ...  Not fleeing       False
#
# [507 rows x 13 columns]

# %%
X_train.shape, Y_train.shape
# Out:
# ((2028, 13), (2028,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((507, 13), (507,))

# %% [markdown]
# ### Logistic Regression

# %%
LogReg = LogisticRegression()
